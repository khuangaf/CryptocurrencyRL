# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/ppo_train/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# 5.66e-06

# %%
df = pd.read_csv('logs/ppo_train_unclip/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# -0.00111979

# %%
pdf = pd.read_csv('logs/ppo/progress.csv')
pdf.tail()
