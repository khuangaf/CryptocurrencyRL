# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/ppo/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-1000:].sum()
# Out:
# 0.01561

# %%
df = pd.read_csv('logs/ppo_4coins/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# -0.00261175

# %%
df = pd.read_csv('logs/ppo_4coins/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# -0.00064557

# %%
pdf = pd.read_csv('logs/ppo/progress.csv')
pdf.tail()
