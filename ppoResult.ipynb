# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/ppo_train_relu_con_con/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-1000:].mean()
# Out:
# -5.2929e-05

# %%
df = pd.read_csv('logs/ppo_train_tanh/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# -0.00227868

# %%
df = pd.read_csv('logs/ppo_train_tanh/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# 4.111e-05

# %%
df = pd.read_csv('logs/ppo_train_relu_con/progress.csv')
df.tail(20)
# Out:
#     policy_entropy  time_elapsed  serial_timesteps  eplenmean  \
# 36        -12.5784  15988.475011           4608000      256.0
# 37        -12.7551  16423.446586           4736000      256.0
# 38        -13.0668  16861.355303           4864000      256.0
# 39        -13.4050  17300.688808           4992000      256.0
# 40        -13.7648  17738.090676           5120000      256.0
# 41        -14.1403  18175.344137           5248000      256.0
# 42        -14.7084  18610.220617           5376000      256.0
# 43        -15.1754  19046.016515           5504000      256.0
# 44             NaN  19480.420965           5632000      256.0
# 45             NaN  19912.790635           5760000      256.0
# 46             NaN  20347.744856           5888000      256.0
# 47             NaN  20779.256979           6016000      256.0
# 48             NaN  21216.019177           6144000      256.0
# 49             NaN  21653.061565           6272000      256.0
# ...

# %%
df = pd.read_csv('logs/ppo_train_relu_con_con/progress.csv')
df.tail(20)
# Out:
#     nupdates  time_elapsed  clipfrac  eprewmean  explained_variance  approxkl  \
# 12     12000   6033.166611  0.175781   0.000008                 NaN  0.005276
# 13     13000   6485.650466  0.300781  -0.000094                 NaN  0.012521
# 14     14000   6938.439118  0.656250  -0.000037                 NaN  0.085253
# 15     15000   7385.595331  0.527344  -0.000050                 NaN  0.056873
# 16     16000   7827.525180  0.404297  -0.000070                 NaN  0.029559
# 17     17000   8283.112836  0.478516  -0.000050                 NaN  0.051105
# 18     18000   8733.100789  0.531250  -0.000045                 NaN  0.048879
# 19     19000   9184.538653  0.439453  -0.000010                 NaN  0.018074
# 20     20000   9636.567817  0.613281  -0.000026                 NaN  0.101521
# 21     21000  10084.298456  0.386719  -0.000016                 NaN  0.019343
# 22     22000  10522.835981  0.384766  -0.000036                 NaN  0.012767
# ...
