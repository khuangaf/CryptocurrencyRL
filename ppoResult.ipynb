# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/ppo_train/monitor.csv', skiprows=1)
df.r[:13000].plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# -4.683e-05

# %%
df = pd.read_csv('logs/ppo_train_tanh/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# -0.00037378

# %%
df = pd.read_csv('logs/ppo_train_relu/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()
print df.r[-100:].mean()
# Out:
# -0.00023363

# %%
df = pd.read_csv('logs/ppo_train_tanh/progress.csv')
df.tail()
# Out:
#      total_timesteps  eplenmean  policy_loss  approxkl    value_loss  \
# 128         16384000      256.0    -0.003738  0.003126  8.660780e-10
# 129         16512000      256.0     0.001912  0.007414  4.076210e-10
# 130         16640000      256.0    -0.005796  0.003978  1.017430e-09
# 131         16768000      256.0    -0.000187  0.001415  8.999840e-10
# 132         16896000      256.0     0.001311  0.000752  1.608270e-09
#
#      clipfrac  policy_entropy  serial_timesteps  time_elapsed  eprewmean  \
# 128  0.095703        -4.43831          16384000  60979.520321  -0.000438
# 129  0.208984        -4.33972          16512000  61472.198925  -0.000460
# 130  0.123047        -4.74990          16640000  61964.178774  -0.000419
# 131  0.068359        -4.73257          16768000  62460.784303  -0.000355
# 132  0.035156        -5.06812          16896000  62955.526460  -0.000331
#
#      nupdates  explained_variance  fps
# 128    128000                 NaN  290
# ...

# %%
df = pd.read_csv('logs/ppo_train_relu/progress.csv')
df.tail()
# Out:
#       value_loss  eprewmean  time_elapsed  explained_variance  nupdates  \
# 94  1.857870e-09  -0.000259  43912.426298                 NaN     94000
# 95  4.771480e-10  -0.000280  44398.093788                 NaN     95000
# 96  1.321010e-09  -0.000253  44879.226865                 NaN     96000
# 97  4.491910e-10  -0.000207  45367.033224                 NaN     97000
# 98  1.393370e-09  -0.000170  45852.173925                 NaN     98000
#
#     eplenmean  serial_timesteps  policy_loss  fps  approxkl  clipfrac  \
# 94      256.0          12032000     0.001315  300  0.002758  0.083984
# 95      256.0          12160000     0.003650  259  0.004344  0.130859
# 96      256.0          12288000     0.003694  282  0.003094  0.169922
# 97      256.0          12416000     0.001142  260  0.001963  0.089844
# 98      256.0          12544000     0.007159  262  0.002145  0.080078
#
#     policy_entropy  total_timesteps
# 94        -6.31121         12032000
# 95        -6.40593         12160000
# ...

# %%
df = pd.read_csv('logs/ppo_train/progress.csv')
df.tail()
# Out:
#      clipfrac  time_elapsed  policy_entropy    value_loss  eplenmean  \
# 133  0.669922  61252.201977        -13.6491  4.713200e-10      256.0
# 134  0.576172  61703.433705        -13.9505  9.087760e-10      256.0
# 135  0.718750  62151.167970        -14.3295  1.300980e-09      256.0
# 136  0.876953  62602.254069        -14.7605  8.048300e-10      256.0
# 137  0.781250  63049.787434        -15.2291  5.476770e-10      256.0
#
#      eprewmean  policy_loss  serial_timesteps  total_timesteps  nupdates  \
# 133  -0.000031     0.083217          17024000         17024000    133000
# 134  -0.000017     0.046360          17152000         17152000    134000
# 135   0.000024     0.193074          17280000         17280000    135000
# 136  -0.000013     1.808830          17408000         17408000    136000
# 137  -0.000007     0.179384          17536000         17536000    137000
#
#      approxkl  explained_variance  fps
# 133  0.102989                 NaN  282
# ...
