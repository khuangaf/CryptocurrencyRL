# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/ppo/monitor.csv', skiprows=1)
df.r.plot(figsize=(18,6))
plt.show()

# %%
pdf = pd.read_csv('logs/ppo/progress.csv')
pdf.tail()
# Out:
#          eprewmean  nupdates  fps  total_timesteps  clipfrac  \
# 1537  4.200000e-07      1538  367           196864       NaN
# 1538  4.200000e-07      1539  342           196992       NaN
# 1539  4.200000e-07      1540  344           197120       NaN
# 1540  4.200000e-07      1541  403           197248       NaN
# 1541  4.300000e-07      1542  308           197376       NaN
#
#       serial_timesteps  explained_variance  time_elapsed   policy_loss  \
# 1537            196864          -48.878567    561.628617 -9.594720e-06
# 1538            196992           -3.971313    562.003274 -2.612240e-06
# 1539            197120          -28.463110    562.375872 -3.844030e-07
# 1540            197248          -41.246944    562.694602 -1.414160e-07
# 1541            197376           -4.220695    563.110144 -5.762560e-08
#
#       value_loss      approxkl  policy_entropy  eplenmean
# 1537    0.000005  4.537850e-09         1.41922      256.0
# 1538    0.000008  6.204650e-10         1.41906      256.0
# 1539    0.000008  4.598920e-11         1.41902      256.0
# 1540    0.000001  4.065640e-12         1.41900      256.0
# 1541    0.000002  8.531510e-13         1.41899      256.0
